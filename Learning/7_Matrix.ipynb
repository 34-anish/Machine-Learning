# %% [markdown]
# # Solution
# [Matrix Math](!https://github.com/codebasics/deep-learning-keras-tf-tutorial/blob/master/4_matrix_math/4_matrix_math.md)

# %% [markdown]
# ![image.png](attachment:image.png)
# *TO Convert Us$ to INR*

# %%
import numpy as np

# %%
revenues = np.array([[200,220,250],[68,79,105],[110,140,180],[80,85,90]])

# %%
revenues*75
# Out:
# array([[15000, 16500, 18750],
#        [ 5100,  5925,  7875],
#        [ 8250, 10500, 13500],
#        [ 6000,  6375,  6750]])

# %% [markdown]
# ![image.png](attachment:image.png)
# **To Find Out the total sales in every month**

# %%
units_sold = np.array([[50,60,25],[10,13,5],[40,70,52]])
ppu = np.array([20,30,15])
np.dot(units_sold,ppu)
# Out:
# array([3175,  665, 3680])
